# %% [markdown]
# # View Demo MRIs and Segmentation

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %%
fileData = nib.load("./demo_image/1/seg_sa.nii.gz").get_fdata()

# %%
fileData.shape
# Out:
# (210, 208, 12, 50)

# %%
imgplot = plt.imshow(fileData[..., 5, 25])
plt.show()
